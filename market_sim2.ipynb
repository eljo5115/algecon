# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
class Market:
    def __init__(self, steps, up_prob=0.5, point_change=0.1):
        self.up_prob = up_prob
        self.point_change = point_change
        self.current_value = 1.0
        self.steps = steps
        self.history = []

    def simulate_market(self):
        for _ in range(self.steps):
            direction = 1 if np.random.rand() < self.up_prob else -1
            self.current_value += direction * self.point_change
            self.history.append(self.current_value)
        return self.current_value

class Agent:
    def __init__(self, risk_function_type, parameter, belief_threshold, sell_threshold):
        self.risk_function_type = risk_function_type
        self.parameter = parameter  # alpha or gamma depending on the type
        self.belief_threshold = belief_threshold
        self.sell_threshold = sell_threshold
        self.bought_at = None
        self.sold_at = None
        self.has_sold = False

    def utility_function(self, x):
        if self.risk_function_type == 'log':
            return math.log(x)

        elif self.risk_function_type == 'exponential':
            alpha = self.parameter
            return -math.exp(-alpha * x)
        
        elif self.risk_function_type == 'power':
            gamma = self.parameter
            if gamma != 1:
                return x**(1 - gamma) / (1 - gamma)
            else:
                return math.log(x)
        
        else:
            raise ValueError("Invalid risk function type")

    def risk_aversion_function(self, market_value):
        return self.utility_function(market_value)
        
    def decide_to_buy(self, market_value, step, total_steps):
        probability_of_up = (total_steps - step) / total_steps
        adjusted_belief = probability_of_up / (1 + self.risk_aversion_function(market_value))

        if adjusted_belief > self.belief_threshold and self.bought_at is None:
            self.bought_at = market_value
            print(f"{self.risk_function_type} bought at: {market_value}")

    def decide_to_sell(self, market_value, step, total_steps):
        if self.bought_at is not None and not self.has_sold:
            probability_of_down = step / total_steps
            adjusted_belief = probability_of_down / (1 + self.risk_aversion_function(market_value))
            if adjusted_belief > self.sell_threshold:
                self.sold_at = market_value
                self.has_sold = True
                print(f"{self.risk_function_type} sold at: {market_value}")

    def calculate_final_value(self, final_market_value):
        if self.bought_at is not None:
            if self.sold_at is not None:
                return self.sold_at / self.bought_at
            else:
                return final_market_value / self.bought_at
        return 1


class LogarithmicAgent(Agent):
    def __init__(self, belief_threshold, sell_threshold):
        super().__init__('log', parameter=None, belief_threshold=belief_threshold, sell_threshold=sell_threshold)


class ExponentialAgent(Agent):
    def __init__(self, alpha, belief_threshold, sell_threshold):
        super().__init__('exponential', parameter=alpha, belief_threshold=belief_threshold, sell_threshold=sell_threshold)


class PowerFunctionAgent(Agent):
    def __init__(self, gamma, belief_threshold, sell_threshold):
        super().__init__('power', parameter=gamma, belief_threshold=belief_threshold, sell_threshold=sell_threshold)

# %%
def simulate_agents_in_market(steps=1000, up_prob=0.51, point_change=0.01):
    market = Market(steps, up_prob, point_change)
    agents = [LogarithmicAgent(1.0,0.5), ExponentialAgent(3,1.0,0.5), PowerFunctionAgent(0.1,0.1,0.5)]
    final_market_value = market.simulate_market()
    final_values = {}

    for step, market_value in enumerate(market.history):
        for agent in agents:
            agent.decide_to_buy(market_value, step, steps)
            agent.decide_to_sell(market_value, step, steps)

    for agent in agents:
        final_values[agent.__class__.__name__] = agent.calculate_final_value(final_market_value)

    return final_values, market.history


def plot_results(final_values, market_history):
    plt.plot(market_history, label='Market Value')
    for agent_type, value in final_values.items():
        plt.scatter(len(market_history) - 1, value, label=f'{agent_type} Final Value')
    plt.xlabel('Time Steps')
    plt.ylabel('Value')
    plt.title('Market Value and Final Agent Value')
    plt.legend()
    plt.show()

# Run the simulation
final_values, market_history = simulate_agents_in_market()
print(final_values)
plot_results(final_values, market_history)
# Out:
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.07
# log sold at: 1.08
# {'LogarithmicAgent': 1.090909090909091, 'ExponentialAgent': 1.0808080808080809, 'PowerFunctionAgent': 1.0707070707070707}

# %%
log_list = []
exp_list = [] 
pow_list = []

for _ in range(100):
    final_values, market_hist = simulate_agents_in_market()
    log_list.append(final_values["LogarithmicAgent"])
    exp_list.append(final_values['ExponentialAgent'])
    pow_list.append(final_values["PowerFunctionAgent"])

print("Log Average:", sum(log_list)/100)
print("Exponential Average:", sum(exp_list)/100)
print("Power Function Average:", sum(pow_list)/100)
# Out:
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.2400000000000002
# log sold at: 1.2800000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.2100000000000002
# log sold at: 1.3100000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8399999999999999
# exponential sold at: 0.8199999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.98
# exponential sold at: 1.08
# log sold at: 1.04
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.9299999999999999
# exponential sold at: 1.1600000000000001
# log sold at: 1.06
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8599999999999999
# exponential sold at: 0.7899999999999998
# power sold at: 0.6899999999999997
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.1700000000000002
# log sold at: 1.1400000000000001
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.02
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1900000000000002
# log sold at: 1.2200000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.01
# log sold at: 1.1400000000000001
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.4500000000000004
# log sold at: 1.2500000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.2800000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.07
# log sold at: 0.99
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.08
# log sold at: 0.98
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.03
# log sold at: 1.0
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.02
# log sold at: 0.99
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# log sold at: 0.8499999999999999
# exponential sold at: 0.8399999999999999
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# log sold at: 0.9299999999999999
# exponential sold at: 1.02
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1600000000000001
# log sold at: 1.1400000000000001
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.2900000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.95
# exponential sold at: 1.3200000000000003
# log sold at: 1.3800000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1900000000000002
# log sold at: 1.09
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.95
# exponential sold at: 1.2400000000000002
# log sold at: 1.4700000000000004
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 0.98
# log sold at: 1.03
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.12
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.01
# log sold at: 0.96
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1600000000000001
# log sold at: 1.09
# power sold at: 0.7399999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.6600000000000006
# log sold at: 1.6900000000000006
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.1400000000000001
# log sold at: 1.2400000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.7499999999999998
# exponential sold at: 0.6799999999999997
# power sold at: 0.8299999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.1300000000000001
# log sold at: 1.1300000000000001
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.01
# log sold at: 1.12
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.4900000000000004
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.3200000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.3200000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.3500000000000003
# log sold at: 1.4900000000000004
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.4000000000000004
# log sold at: 1.4700000000000004
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 0.99
# log sold at: 0.96
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.94
# exponential sold at: 0.94
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.97
# exponential sold at: 1.2900000000000003
# log sold at: 1.2400000000000002
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.07
# log sold at: 1.01
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.9299999999999999
# exponential sold at: 0.9099999999999999
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.1300000000000001
# log sold at: 1.12
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# log sold at: 0.9299999999999999
# exponential sold at: 0.9099999999999999
# power sold at: 0.8099999999999998
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.4000000000000004
# log sold at: 1.6100000000000005
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.4800000000000004
# log sold at: 1.7700000000000007
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# log sold at: 0.8599999999999999
# exponential sold at: 0.8999999999999999
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.6499999999999997
# log sold at: 0.6499999999999997
# exponential sold at: 0.6399999999999997
# power sold at: 0.5499999999999996
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.12
# log sold at: 1.3200000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8599999999999999
# exponential sold at: 0.95
# power sold at: 0.7799999999999998
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1300000000000001
# log sold at: 1.2000000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.09
# log sold at: 1.2200000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.9199999999999999
# exponential sold at: 0.95
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 0.96
# log sold at: 0.95
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8299999999999998
# exponential sold at: 0.8499999999999999
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.3500000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.3700000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.4200000000000004
# log sold at: 1.2900000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.3900000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.02
# log sold at: 1.02
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.5500000000000005
# log sold at: 1.5500000000000005
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.4000000000000004
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.4000000000000004
# log sold at: 1.2700000000000002
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.3200000000000003
# log sold at: 1.3700000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.2100000000000002
# log sold at: 1.4000000000000004
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.2300000000000002
# log sold at: 1.1600000000000001
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.6400000000000006
# log sold at: 1.7400000000000007
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.07
# log sold at: 1.1500000000000001
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1900000000000002
# log sold at: 1.1300000000000001
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1700000000000002
# log sold at: 1.1700000000000002
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.97
# log sold at: 0.7899999999999998
# exponential sold at: 0.7399999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.08
# power sold at: 0.6899999999999997
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.3700000000000003
# log sold at: 1.2900000000000003
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.07
# log sold at: 1.05
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.5700000000000005
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.12
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 0.8899999999999999
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.08
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# log sold at: 0.6099999999999997
# exponential sold at: 0.4499999999999995
# power sold at: 0.5799999999999996
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.9299999999999999
# exponential sold at: 0.94
# power sold at: 0.8399999999999999
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.12
# log sold at: 1.03
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.99
# exponential sold at: 1.5500000000000005
# log sold at: 1.5600000000000005
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8599999999999999
# exponential sold at: 0.94
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.95
# log sold at: 0.8199999999999998
# exponential sold at: 0.7699999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.5500000000000005
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.97
# log sold at: 0.7599999999999998
# exponential sold at: 0.8799999999999999
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.01
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.3200000000000003
# power sold at: 0.7599999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.97
# log sold at: 0.8299999999999998
# exponential sold at: 0.7799999999999998
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.4200000000000004
# exponential bought at: 1.01
# power bought at: 1.01
# log bought at: 0.9099999999999999
# exponential sold at: 1.3000000000000003
# log sold at: 1.2900000000000003
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 0.9299999999999999
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8799999999999999
# exponential sold at: 0.8599999999999999
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.5700000000000005
# log sold at: 1.6100000000000005
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.12
# log sold at: 1.08
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.04
# log sold at: 1.1
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# log sold at: 0.8699999999999999
# exponential sold at: 0.94
# power sold at: 0.7499999999999998
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1300000000000001
# log sold at: 1.2200000000000002
# exponential bought at: 1.01
# power bought at: 1.01
# exponential sold at: 1.5000000000000004
# log bought at: 0.99
# exponential bought at: 0.99
# power bought at: 0.99
# exponential sold at: 1.1
# log sold at: 1.08
# Log Average: 1.1270865800618786
# Exponential Average: 1.137647764776478
# Power Function Average: 1.2569516951695172
